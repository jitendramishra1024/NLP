# %%
#PART 01 :
#DATASET OBTAINED FROM 
#https://www.kaggle.com/sebastienverpile/consumercomplaintsdata
#DATA EXPLORATION 
import pandas as pd
#df = pd.read_csv('Consumer_Complaints.csv')
df = pd.read_csv(r'C:\ACAD_GLD\NLP_JULY_GIT\NLP\08. MODEL_COMPARISION_FOR_CONSUMER_COMPLAINT_CLASSIFICATION\Consumer_Complaints_large.csv')
df =df.rename(columns={"Consumer complaint narrative": "Consumer Complaint"})
df.head()
# Out:
#   Date received           Product     Sub-product  \
# 0     3/12/2014          Mortgage  Other mortgage
# 1     10/1/2016  Credit reporting             NaN
# 2    10/17/2016     Consumer Loan    Vehicle loan
# 3      6/8/2014       Credit card             NaN
# 4     9/13/2014   Debt collection     Credit card
#
#                                       Issue                   Sub-issue  \
# 0  Loan modification,collection,foreclosure                         NaN
# 1    Incorrect information on credit report              Account status
# 2                Managing the loan or lease                         NaN
# 3                                Bankruptcy                         NaN
# 4                     Communication tactics  Frequent or repeated calls
#
#                                   Consumer Complaint  \
# 0                                                NaN
# 1  I have outdated information on my credit repor...
# 2  I purchased a new car on XXXX XXXX. The car de...
# 3                                                NaN
# 4                                                NaN
#
#                              Company public response  \
# 0                                                NaN
# 1  Company has responded to the consumer and the ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                   Company State ZIP code            Tags  \
# 0                    M&T BANK CORPORATION    MI    48382             NaN
# 1  TRANSUNION INTERMEDIATE HOLDINGS, INC.    AL    352XX             NaN
# 2          CITIZENS FINANCIAL GROUP, INC.    PA    177XX  Older American
# 3                AMERICAN EXPRESS COMPANY    ID    83854  Older American
# 4                          CITIBANK, N.A.    VA    23233             NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0                        NaN      Referral            3/17/2014
# 1           Consent provided           Web            10/5/2016
# 2           Consent provided           Web           10/20/2016
# 3                        NaN           Web            6/10/2014
# 4                        NaN           Web            9/13/2014
#
#   Company response to consumer Timely response? Consumer disputed?  \
# 0      Closed with explanation              Yes                 No
# 1      Closed with explanation              Yes                 No
# 2      Closed with explanation              Yes                 No
# 3      Closed with explanation              Yes                Yes
# 4      Closed with explanation              Yes                Yes
#
#    Complaint ID
# 0        759217
# 1       2141773
# 2       2163100
# 3        885638
# 4       1027760

# %%
df.shape
# Out:
# (903983, 18)

# %%
#UNDERSTAND DATA 

df=df.sample(10000)
df.head()
# Out:
#        Date received                                            Product  \
# 194988    12/27/2016                                           Mortgage
# 663723     8/14/2015                                   Credit reporting
# 782283    11/14/2012                                           Mortgage
# 722604     11/4/2016                                    Debt collection
# 839668     9/28/2017  Credit reporting, credit repair services, or o...
#
#              Sub-product                                              Issue  \
# 194988    Other mortgage           Loan modification,collection,foreclosure
# 663723               NaN             Incorrect information on credit report
# 782283    Other mortgage           Loan modification,collection,foreclosure
# 722604       Payday loan              Cont'd attempts collect debt not owed
# 839668  Credit reporting  Problem with a credit reporting company's inve...
#
#                                                 Sub-issue  \
# 194988                                                NaN
# 663723                                     Account status
# 782283                                                NaN
# 722604                                   Debt is not mine
# 839668  Difficulty submitting a dispute or getting inf...
#
#                                        Consumer Complaint  \
# 194988  1. In XXXX, we were placed in foreclosure in v...
# 663723                                                NaN
# 782283                                                NaN
# 722604                                                NaN
# 839668                                                NaN
#
#                                  Company public response  \
# 194988                                               NaN
# 663723  Company chooses not to provide a public response
# 782283                                               NaN
# 722604                                               NaN
# 839668                                               NaN
#
#                                     Company State ZIP code Tags  \
# 194988                  NATIONSTAR MORTGAGE    CA    956XX  NaN
# 663723  Experian Information Solutions Inc.    OH    44035  NaN
# 782283                WELLS FARGO & COMPANY    GA    30152  NaN
# 722604           CURO Intermediate Holdings    AZ    85355  NaN
# 839668                        EQUIFAX, INC.    NC    282XX  NaN
#
#        Consumer consent provided? Submitted via Date sent to company  \
# 194988           Consent provided           Web           12/27/2016
# 663723                        NaN   Postal mail            8/24/2015
# 782283                        NaN      Referral           11/15/2012
# 722604                        NaN         Phone            11/8/2016
# 839668                        NaN           Web            9/28/2017
#
#            Company response to consumer Timely response? Consumer disputed?  \
# 194988          Closed with explanation              Yes                 No
# 663723  Closed with non-monetary relief              Yes                 No
# 782283          Closed with explanation              Yes                Yes
# 722604          Closed with explanation              Yes                 No
# 839668          Closed with explanation              Yes                NaN
#
#         Complaint ID
# 194988       2265613
# 663723       1520140
# 782283        190717
# 722604       2197210
# 839668       2687525

# %%
print(df.shape)
print("After removing null comments")
#remove null review comments 
df= df[pd.notnull(df['Consumer Complaint'])]
print(df.shape)
# Out:
# (10000, 18)
# After removing null comments
# (2202, 18)

# %%
df['Product'].value_counts()
# Out:
# Debt collection                                                                 528
# Mortgage                                                                        383
# Credit reporting                                                                370
# Credit card                                                                     197
# Bank account or service                                                         172
# Credit reporting, credit repair services, or other personal consumer reports    161
# Student loan                                                                    148
# Consumer Loan                                                                   104
# Credit card or prepaid card                                                      38
# Checking or savings account                                                      24
# Payday loan                                                                      23
# Prepaid card                                                                     15
# Money transfers                                                                  14
# Payday loan, title loan, or personal loan                                         7
# Vehicle loan or lease                                                             7
# Money transfer, virtual currency, or money service                                7
# Other financial service                                                           3
# Virtual currency                                                                  1
# Name: Product, dtype: int64

# %%
df.loc[(df['Product'] == 'Virtual currency'),'Product']='Other financial service'
df.loc[(df['Product'] == 'Payday loan, title loan, or personal loan'),'Product']='Other financial service'
df.loc[(df['Product'] == 'Money transfer, virtual currency, or money service'),'Product']='Other financial service'
df.loc[(df['Product'] == 'Vehicle loan or lease'),'Product']='Other financial service'

df.head()
# Out:
#        Date received                  Product     Sub-product  \
# 194988    12/27/2016                 Mortgage  Other mortgage
# 625309      8/4/2015         Credit reporting             NaN
# 265639     6/10/2017  Other financial service     Payday loan
# 530493     4/13/2017          Debt collection     Payday loan
# 521070     7/30/2015              Credit card             NaN
#
#                                                     Issue  \
# 194988           Loan modification,collection,foreclosure
# 625309             Incorrect information on credit report
# 265639  Was approved for a loan, but didn't receive th...
# 530493              Cont'd attempts collect debt not owed
# 521070                                              Other
#
#                                 Sub-issue  \
# 194988                                NaN
# 625309                      Account terms
# 265639                                NaN
# 530493  Debt was discharged in bankruptcy
# 521070                                NaN
#
#                                        Consumer Complaint  \
# 194988  1. In XXXX, we were placed in foreclosure in v...
# 625309  RE : XXXX XXXX XXXX ( XXXX ) /XXXX ( XXXX ) In...
# 265639  XXXX   XXXX   notified me that  USAA  is not r...
# 530493  This debt was cleared in chapter XXXX - they h...
# 521070  THERE ARE XXXX INQUIRES ON MY CREDIT REPORT FR...
#
#                                   Company public response  \
# 194988                                                NaN
# 625309                                                NaN
# 265639  Company believes it acted appropriately as aut...
# 530493  Company believes it acted appropriately as aut...
# 521070                                                NaN
#
#                                        Company State ZIP code            Tags  \
# 194988                     NATIONSTAR MORTGAGE    CA    956XX             NaN
# 625309                           EQUIFAX, INC.    GA    314XX  Older American
# 265639  UNITED SERVICES AUTOMOBILE ASSOCIATION    WA    983XX             NaN
# 530493                          CASHCALL, INC.    AL    350XX             NaN
# 521070                     SYNCHRONY FINANCIAL    NC    271XX             NaN
#
#        Consumer consent provided? Submitted via Date sent to company  \
# 194988           Consent provided           Web           12/27/2016
# 625309           Consent provided           Web             8/5/2015
# 265639           Consent provided           Web            6/12/2017
# 530493           Consent provided           Web            4/13/2017
# 521070           Consent provided           Web            7/30/2015
#
#            Company response to consumer Timely response? Consumer disputed?  \
# 194988          Closed with explanation              Yes                 No
# 625309          Closed with explanation              Yes                 No
# 265639          Closed with explanation              Yes                NaN
# 530493          Closed with explanation              Yes                 No
# 521070  Closed with non-monetary relief              Yes                 No
#
#         Complaint ID
# 194988       2265613
# 625309       1502479
# 265639       2532548
# 530493       2431555
# 521070       1495693

# %%
df['Product'].value_counts()
# Out:
# Debt collection                                                                 528
# Mortgage                                                                        383
# Credit reporting                                                                370
# Credit card                                                                     197
# Bank account or service                                                         172
# Credit reporting, credit repair services, or other personal consumer reports    161
# Student loan                                                                    148
# Consumer Loan                                                                   104
# Credit card or prepaid card                                                      38
# Other financial service                                                          25
# Checking or savings account                                                      24
# Payday loan                                                                      23
# Prepaid card                                                                     15
# Money transfers                                                                  14
# Name: Product, dtype: int64

# %%
#remove duplicates 
#df=df.drop_duplicates()
#remove all column except input and output 
col = ['Product', 'Consumer Complaint']
df= df[col]
#remove null review comments 
df= df[pd.notnull(df['Consumer Complaint'])]
#rename the column from Consumer Complaint to Consumer_complaint
df.columns=['Product', 'Consumer_complaint']
#factorize the product and rename with categoryid 
df['category_id'] = df['Product'].factorize()[0]

# %%
#preserve mapping of product to category id mapping 
category_id_df = df[['Product', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'Product']].values)
id_to_category
# Out:
# {0: 'Mortgage',
#  1: 'Credit reporting',
#  2: 'Other financial service',
#  3: 'Debt collection',
#  4: 'Credit card',
#  5: 'Credit reporting, credit repair services, or other personal consumer reports',
#  6: 'Checking or savings account',
#  7: 'Bank account or service',
#  8: 'Student loan',
#  9: 'Credit card or prepaid card',
#  10: 'Consumer Loan',
#  11: 'Payday loan',
#  12: 'Prepaid card',
#  13: 'Money transfers'}

# %%
#take only relevant column 
col = ['Consumer_complaint','category_id']
df= df[col]
df=df.reset_index()
df=df.drop(columns=['index'])
df.head()
# Out:
#                                   Consumer_complaint  category_id
# 0  1. In XXXX, we were placed in foreclosure in v...            0
# 1  RE : XXXX XXXX XXXX ( XXXX ) /XXXX ( XXXX ) In...            1
# 2  XXXX   XXXX   notified me that  USAA  is not r...            2
# 3  This debt was cleared in chapter XXXX - they h...            3
# 4  THERE ARE XXXX INQUIRES ON MY CREDIT REPORT FR...            4

# %%
#check distribution
#see number of different category id available 
df['category_id'].value_counts()
#we have 16 categories
# Out:
# 3     528
# 0     383
# 1     370
# 4     197
# 7     172
# 5     161
# 8     148
# 10    104
# 9      38
# 2      25
# 6      24
# 11     23
# 12     15
# 13     14
# Name: category_id, dtype: int64

# %%
df.shape
# Out:
# (2202, 2)

# %%
#DATA CLEANING 
#DATA CLEANING 
import re
import nltk
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
nltk.download('punkt')
nltk.download('stopwords')
lemmatizer = WordNetLemmatizer()
ps = PorterStemmer()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\INE12363221\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\INE12363221\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
def clean_text(df):
    all_reviews = list()
    lines = df["Consumer_complaint"].values.tolist()
    for text in lines:
        text = text.lower()
        text = re.sub('[^a-zA-Z]', ' ', text)
        text = text.replace('x', '')
        #remove single character 
        #text = re.sub('\s\w\s',' ',text)
        words=nltk.word_tokenize(text)
        stop_words= set(stopwords.words('english'))
        stop_words.discard("not")
        words_without_stop_words=[word for word in words if word not in stop_words]
        words=words_without_stop_words
        #words=[lemmatizer.lemmatize(word) for word in words_without_stop_words ]
        #words=[ps.stem(word) for word in words_without_stop_words ]
        words = ' '.join(words)
        all_reviews.append(words)
    return all_reviews

#  'chase oh may concern last letter received chase still n take responsibility liability damage created family borrowers point following errors made chase mortgage department every time simple ignored chase paid property taes without knowledge consent two times records indicated confirmed ta authorities borrowers never late property taes therefore need chase paid property taes behalf without approval consent fraud case escalate federal level result persecution paid fines fees imprisonment people involved would n first case large bank tried get news cases like chase opened escrow account without knowledge consent agreement borrowers never advice open escrow account insurance property taes initially entered agreement chase finance property never brought attention escrow accounts chase n authority open escrow accounts without consulting borrowers another case escalating federal court justice later dated chase talks short payments borrowers never made short payment mortgage chase errors funds applied mortgage know chase process mortgage payments manually perhaps miss applied many mortgage payments erroneously shown schedule never late delinquent mortgage payments chase collections calls not necessary contrary disturbing line regards chase employees representatives chase made another error account opens mortgage assistance review accounts borrowers not request mortgage assistance implied one chase admitted error proving saying time chase made many errors account got enough go congress federal court system need received appraisal review packaged current home pictures unit chase violated privacy act us borrowers took pictures without proper knowledge consent found disturbing unprofessional chase employees chase violated rights safe quiet enjoyment borrowers found chase personnel liable appraisal report done error sending us mortgage assistance program never applied not routine appraisal never appraisal routine routine times life loan since know fact routine appraisal false statement chase employees mistakes errors committed chase employees persecuted court law punishable material damages borrowers made mortgage payments chase approimately amount today chase increasing interest rate mortgage payments increasing results incidents errors caused chase employees requesting chase reduce principal negotiate principal balance simple',
#  'student loan servicer fedloan servicing several years income based repayment ibr plan monthly payments automatically deducted checking account start repayment period recently issues payments always made time late last year applied transition ibr new repaye plan would save nearly month months later still waiting switch happen process complete nightmare called repeatedly check status find steps could take epedite process continue told process underway instances given conflicting advice information fedloan servicing employees supervisors eample informed supervisor needed make forbearance payment complete switch made payment told later another employee payment not fact anything advance process payment simply applied balance not affect ibr repaye process fedloan servicing make separate payment assured payment thing needed finish switch repaye employee even told would request process epedited yet month later still waiting called today told payment not count short simply paid told employee spoke told recurring problem others situation received payment request today made third time payment purportedly last step process clear fedloan servicing apparently removed ibr currently standard repayment plan repayment terms plan far onerous make repeated forbearance requests wait fedloan servicing move repaye believe transition ibr repaye completely mishandled fedloan servicing not take si months make switch repayment plan another gone several years consistent time payments record several forbearances much smoother suspect things would even worse not repeatedly called fedloan servicing also incredibly intend take advantage public service loan forgiveness pslf month forbearance wait put onto repaye not making time qualifying payments count toward plsf sad part position make payments right either ibr repaye fedloan servicing left stuck standard repayment purgatory actions fedloan servicing made benefits repaye illusory individuals like fear borrowers situation',
#  'eqifa problem receiving free annual credit report contact eqifa reply stating nothing website annual credit report com not eplain cant receive annual credit report',
#  'reviewing yearly credit report noticed santander bank access credit without knowledge permission contacted via certified mail epressing concerns unlawfully running credit not receive response received letter',
#  'graduated university degree currently owe navient private loans private loans interest rate even unfavorable repayment term interested consolidating various private student loans favorable loan lower interest rate appropriate repayment term afraid options fleibility enjoyed many people across country variety loans not apply private loan please advice regarding current situation private loans possible solutions people like']

# %%
df['Cleaned_consumer_complaint']=all_complaint
df=df.drop(columns=['Consumer_complaint'])
df.to_csv('cleaned_consumer_complaint.csv')
df.head()
# Out:
#    category_id                         Cleaned_consumer_complaint
# 0            0  placed foreclosure violation ca homeowners ill...
# 1            1  response correspondence received dated enclose...
# 2            2  notified usaa not relaying information timely ...
# 3            3  debt cleared chapter told repeatedly since sta...
# 4            4            inquires credit report company shouldnt
